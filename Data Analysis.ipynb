# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("C:\\Users\\kayalvizhi\\Downloads\\Dataset\\Pizza_Sale.csv",)
data
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0             1         1     hawaiian_m         1    1/1/2015   11:38:36
# 1             2         2  classic_dlx_m         1    1/1/2015   11:57:40
# 2             3         2  five_cheese_l         1    1/1/2015   11:57:40
# 3             4         2    ital_supr_l         1    1/1/2015   11:57:40
# 4             5         2     mexicana_m         1    1/1/2015   11:57:40
# ...         ...       ...            ...       ...         ...        ...
# 48615     48616     21348  ckn_alfredo_m         1  31-12-2015   21:23:10
# 48616     48617     21348  four_cheese_l         1  31-12-2015   21:23:10
# 48617     48618     21348   napolitana_s         1  31-12-2015   21:23:10
# 48618     48619     21349     mexicana_l         1  31-12-2015   22:09:54
# 48619     48620     21350      bbq_ckn_s         1  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48604 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  object
#  5   order_time         48620 non-null  object
#  6   unit_price         48620 non-null  float64
#  7   total_price        48613 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48597 non-null  object
#  10  pizza_ingredients  48607 non-null  object
#  11  pizza_name         48613 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
data.isnull().sum()
# Out:
# pizza_id              0
# order_id              0
# pizza_name_id        16
# quantity              0
# order_date            0
# order_time            0
# unit_price            0
# total_price           7
# pizza_size            0
# pizza_category       23
# pizza_ingredients    13
# pizza_name            7
# dtype: int64

# %% [markdown]
# We got some missing values in few columns as it is very low so we can drop them.

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# pizza_id             0
# order_id             0
# pizza_name_id        0
# quantity             0
# order_date           0
# order_time           0
# unit_price           0
# total_price          0
# pizza_size           0
# pizza_category       0
# pizza_ingredients    0
# pizza_name           0
# dtype: int64

# %%
data.describe()
# Out:
#            pizza_id      order_id      quantity    unit_price   total_price
# count  48554.000000  48554.000000  48554.000000  48554.000000  48554.000000
# mean   24342.866458  10715.733081      1.019648     16.493957     16.821744
# std    14017.563232   6172.205962      0.143172      3.621876      4.438471
# min        1.000000      1.000000      1.000000      9.750000      9.750000
# 25%    12205.250000   5360.250000      1.000000     12.750000     12.750000
# 50%    24343.500000  10702.000000      1.000000     16.500000     16.500000
# 75%    36481.750000  16107.750000      1.000000     20.250000     20.500000
# max    48620.000000  21350.000000      4.000000     35.950000     83.000000

# %%
data.corr()
# Out:
#              pizza_id  order_id  quantity  unit_price  total_price
# pizza_id     1.000000  0.999990  0.003329   -0.003211    -0.000951
# order_id     0.999990  1.000000  0.003311   -0.003249    -0.000994
# quantity     0.003329  0.003311  1.000000    0.007154     0.542162
# unit_price  -0.003211 -0.003249  0.007154    1.000000     0.835934
# total_price -0.000951 -0.000994  0.542162    0.835934     1.000000

# %%
data['order_date']=pd.to_datetime(data['order_date'])
data['order_time']=pd.to_datetime(data['order_time'])
# Out:
# C:\Users\kayalvizhi\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13-01-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\kayalvizhi\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14-01-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\kayalvizhi\anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '15-01-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48620 entries, 0 to 48619
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pizza_id           48620 non-null  int64
#  1   order_id           48620 non-null  int64
#  2   pizza_name_id      48604 non-null  object
#  3   quantity           48620 non-null  int64
#  4   order_date         48620 non-null  datetime64[ns]
#  5   order_time         48620 non-null  datetime64[ns]
#  6   unit_price         48620 non-null  float64
#  7   total_price        48613 non-null  float64
#  8   pizza_size         48620 non-null  object
#  9   pizza_category     48597 non-null  object
#  10  pizza_ingredients  48607 non-null  object
#  11  pizza_name         48613 non-null  object
# dtypes: datetime64[ns](2), float64(2), int64(3), object(5)
# memory usage: 4.5+ MB

# %%
data.unit_price.max()
# Out:
# 35.95

# %%
data.unit_price.min()
# Out:
# 9.75

# %%
pizza_name=data.groupby('pizza_name_id')['total_price'].sum().reset_index()
pizza_name
# Out:
#     pizza_name_id  total_price
# 0       bbq_ckn_l     20563.25
# 1       bbq_ckn_m     15996.25
# 2       bbq_ckn_s      6171.00
# 3      big_meat_s     22968.00
# 4    brie_carre_s     11588.50
# ..            ...          ...
# 86   the_greek_xl     14076.00
# 87  the_greek_xxl      1006.60
# 88   veggie_veg_l      8646.75
# 89   veggie_veg_m     10160.00
# 90   veggie_veg_s      5568.00
#
# [91 rows x 2 columns]

# %%
pizza_name1=data.groupby('pizza_name')['total_price'].count().reset_index()
pizza_name1
# Out:
#                                     pizza_name  total_price
# 0                   The Barbecue Chicken Pizza         2371
# 1                           The Big Meat Pizza         1810
# 2                         The Brie Carre Pizza          480
# 3                          The Calabrese Pizza          927
# 4                 The California Chicken Pizza         2302
# 5                    The Chicken Alfredo Pizza          980
# 6                      The Chicken Pesto Pizza          961
# 7                     The Classic Deluxe Pizza         2416
# 8                        The Five Cheese Pizza         1358
# 9                        The Four Cheese Pizza         1849
# 10                             The Greek Pizza         1406
# 11                      The Green Garden Pizza          987
# 12                          The Hawaiian Pizza         2369
# 13                 The Italian Capocollo Pizza         1413
# 14                   The Italian Supreme Pizza         1849
# ...

# %%
data.value_counts('pizza_name').nlargest(20).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pizza_name'>

# %%
data.value_counts('pizza_category').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pizza_category'>

# %%
data.value_counts('pizza_size').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='pizza_size'>

# %%
pizza_size=data.groupby('pizza_size')['total_price'].sum().reset_index()
pizza_size
# Out:
#   pizza_size  total_price
# 0          L    375259.20
# 1          M    249334.75
# 2          S    178066.75
# 3         XL     14076.00
# 4        XXL      1006.60

# %%
pizza_size.plot(kind='bar',x='pizza_size',y='total_price')
# Out:
# <AxesSubplot:xlabel='pizza_size'>

# %%
total_order=data.groupby('order_date')['order_id'].count().reset_index()
total_order
# Out:
#     order_date  order_id
# 0   2015-01-01       161
# 1   2015-01-02       188
# 2   2015-01-03        99
# 3   2015-01-04       133
# 4   2015-01-05       152
# ..         ...       ...
# 353 2015-12-27        87
# 354 2015-12-28       102
# 355 2015-12-29        77
# 356 2015-12-30        73
# 357 2015-12-31       171
#
# [358 rows x 2 columns]

# %%
data.groupby('order_date')['pizza_name_id'].nunique().reset_index()
# Out:
#     order_date  pizza_name_id
# 0   2015-01-01             67
# 1   2015-01-02             72
# 2   2015-01-03             53
# 3   2015-01-04             61
# 4   2015-01-05             72
# ..         ...            ...
# 353 2015-12-27             55
# 354 2015-12-28             64
# 355 2015-12-29             48
# 356 2015-12-30             49
# 357 2015-12-31             70
#
# [358 rows x 2 columns]

# %%
data.groupby('order_date')['total_price'].sum().reset_index()
# Out:
#     order_date  total_price
# 0   2015-01-01      2713.85
# 1   2015-01-02      3189.20
# 2   2015-01-03      1598.55
# 3   2015-01-04      2176.85
# 4   2015-01-05      2571.95
# ..         ...          ...
# 353 2015-12-27      1419.00
# 354 2015-12-28      1637.20
# 355 2015-12-29      1353.25
# 356 2015-12-30      1337.80
# 357 2015-12-31      2916.00
#
# [358 rows x 2 columns]

# %% [markdown]
# Findings
# This data analysis is about pizza sales
# *Removed the null values because it is less in count
# * The data has no duplicate values
# * The The Classic Deluxe Pizza is top in the sales
# * The size L is top in the sales
# * The Classic Pizza category dominating in the sales
# * The The Classic Deluxe Pizza is the least in the sales
